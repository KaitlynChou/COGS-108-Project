# %% [markdown]
# **If you lost points on the last checkpoint you can get them back by responding to TA/IA feedback**
#
# Update/change the relevant sections where you lost those points, make sure you respond on GitHub Issues to your TA/IA to call their attention to the changes you made here.
#
# Please update your Timeline... no battle plan survives contact with the enemy, so make sure we understand how your plans have changed.

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# # Names
#
# - Kaitlyn Chou
# - Aria Gross Villa
# - Alera Ojomoh-dermody
# - Isaac Roberts
# - Angelina Vo

# %% [markdown]
# # Research Question

# %% [markdown]
# Does participation (number of registered users, amount of content circulated, programs attended) at libraries in California counties correlate to CAASPP test scores (ELA and Mathematics) of students attending school in those counties?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Standardized tests can act as a lens through which educators and policymakers can understand various aspects of the educational system, identifying both strengths and areas in need of improvement. Analyzing standardized test results alongside teacher credentials, resource allocation, and instructional strategies provides a comprehensive view of the educational environment, fostering efforts to improve student achievement and success. The No Child Left Behind (NCLB) Act mandated that schools employ qualified educators who are certified in their state, hold a bachelor's degree, and demonstrate subject knowledge. <a name="cite_ref-3"></a>[<sup>1</sup>](#cite_note-3) With the replacement of NCLB by the Every Child Succeeds Act (ECSA) in 2015, schools, or Local Education Agencies, are now obligated to report on the qualifications of educators, including the percentage of 'inexperienced' teachers. <a name="cite_ref-3"></a>[<sup>2</sup>](#cite_note-3)
#
# Numerous research papers have explored the influence of libraries on individual students' educational attainment. Across the three initial research sources we examined, student success was measured and defined using metrics such as GPAs, retention rates, and qualitative interviews, shedding light on students' perspectives regarding the significance of public libraries in their academic journey. Just as GPA and retention rates provide insights, CAASPP test scores in ELA and mathematics offer pathways to explore the connection between public library utilization and measurable academic achievement. While standardized testing is not the sole dependable method for gauging student progress, it remains commonly utilized to assess college readiness and academic advancement.
#
# The literature asserts that public libraries serve as invaluable resources for students from diverse socioeconomic backgrounds, offering access to a wide range of written, verbal, and digital materials. For students lacking reliable technology, libraries provide a conducive environment for studying, asking questions, and engaging in group activities, all within a quiet and secure setting. Meanwhile, school librarians act as threads, linking students and teachers to reliable, consistently accurate instruction. Libraries not only supply tangible resources to all community members but can also serve as academic equalizers for low-income students and students of color. A study conducted on Australian public libraries' impact on students living in regional or remote locations found that these students benefited significantly from utilizing library resources.<a name="cite_ref-2"></a>[<sup>3</sup>](#cite_note-2) This was attributed to their access to qualified and informed assistance from librarians, as well as the diversity of materials available in libraries. A study conducted at Northern Colorado University from fall 2017 to spring 2018 revealed that a higher proportion of students of color and those eligible for Pell grants utilized library resources compared to their white or non-eligible counterparts.<a name="cite_ref-1"></a>[<sup>4</sup>](#cite_note-1) The Northern Colorado University study posed several empirical questions related to student success, which could be investigated using the metrics mentioned earlier. Questions include: “How does the use of specific library services correlate with persistence for undergraduate students?” and, “Is there a positive correlation between the number of uses of library services and academic achievement for undergraduate students?”. <a name="cite_ref-1"></a>[<sup>5</sup>](#cite_note-1)
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Mayer, Jennifer; Dineen, Rachel; Rockwell, Angela; and Blodgett, Jayne. 'Undergraduate Student Success and Library Use: A Multimethod Approach.' University Libraries Faculty Publications, 2020. Available at: https://digscholarship.unco.edu/libfacpub/96
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Power, Emma et al. ''Working Together': Public Libraries Supporting Rural, Regional, and Remote Low-Socioeconomic Student Success in Partnership with Universities.' Journal Name, vol. [volume number], no. [issue number], 2019, pp. 105-125. DOI: https://doi.org/10.1080/24750158.2019.1608497
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Tomasetti, Elena T. 'Factors That Contribute to a Score Increase from Eighth to Eleventh Grade on the CAASPP Mathematics Exam at Red Bluff High School.' Master's thesis, California State University, Chico, 2022.

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We hypothesize that California counties with higher rates of activity and participation in public libraries correlate positively with higher CAASPP (California Assessment of Student Performance and Progress) test scores in both ELA and mathematics. Children who regularly visit libraries  have more exposure to reading, routine studying, tutoring, and community events that are often held by libraries. We hypothesize that this would result in those children having stronger reading comprehension and understanding of other skills that lead to them scoring higher on California standardized tests than those who don’t.

# %% [markdown]
# # Data

# %% [markdown]
# ## Data Overview
#
# ### Dataset #1
# Dataset Name: California Public Libraries Statistics
#
# Link to the dataset: https://www.library.ca.gov/stats/?pageNo=1
#
# Number of observations: 6 years (2016-2022), 184-186 libraries (observations) each
#
# Number of variables: Before wrangling, 119 variables. After wrangling, we should have 9: 'County', 'Population of The Legal Service Area', 'Registered Users as of June 30', 'Children Borrowers', 'Library Visits', 'Total Operating Income', 'Circulation of Childrens Materials', "# of Children's Programs", "Children's Program Attendance"
#
# The most important variables we will use to determine the rate of school-aged children’s activity in libraries are Children Borrowers and Circulation of Children’s Materials. Children borrowers are those who are registered with the library with a child/youth library card, but specific age can vary by library system. Circulation of Children’s Materials refers to the total circulation (including renewals) of cataloged and uncataloged materials (in all formats) marked as Children's, whether they are borrowed by a child, young adult, or adult over the course of the report year. We will calculate the borrowers and circulation per 1,000 children in the county using the population of children in each county using Dataset #3 (see below).
#
# ### Dataset #2
# Dataset Name: California Assessment of Student Performance and Progress (CAASPP) Smarter Balanced Assessments
#
# Link to the dataset: [CAASPP Data](https://caaspp-elpac.ets.org/caaspp/ResearchFileListSB?ps=true&lstTestYear=2023&lstTestType=B&lstCounty=00&lstDistrict=00000&lstFocus=a),  [Key for variables](https://caaspp-elpac.ets.org/caaspp/ResearchFileFormatSB?ps=true&lstTestYear=2023&lstTestType=B)
#
# Number of observations: 8 years (2014 - 2023, missing data from 2019-2020), ~101,000 observations in the score dataset (each observation is a grade in a school), ~11,000 observations in the school names dataset (each observation is a school). We will be using data from grades 3 through 8, excluding grade 11 because the age range falls outside the Children Borrowers’ age range from the Library dataset. This dataset includes CAASPP data from charter and non-charter schools, both of which will be included in our analysis.
#
# Number of variables: Before wrangling, 33 variables. After wrangling, we should have 10: 'County Code', 'School Code', 'Test Year', ‘Test ID’, 'Total Tested with Scores', 'Mean Scale Score', 'Percentage Standard Exceeded', 'Percentage Standard Met', 'Percentage Standard Nearly Met', 'Percentage Standard Not Met'
#
# We will primarily be focusing on the Mean Scale Scores for the ELA and the Mathematics assessments as it represents the average score across all content areas on the exam for each grade but will use the Percentage Standard data to go deeper with our analysis. A Test ID of 1 or 2 corresponds to the ELA or the Mathematics assessments respectively. The CAASPP website provides definitions of what each standard level means and how the percentages met were calculated on [this](https://caaspp-elpac.ets.org/caaspp/UnderstandingSBResults#am1) page and how the Mean Scale Score was calculated and what the ranges for each grade is [here](https://caaspp-elpac.ets.org/caaspp/ScaleScoreRangesSB).
#
# Each year has two files, one for score data by school and grade, and one that matches school codes with the school names. We will combine these two sets for each year so that the scores are identifiable by county name rather than code. We plan to combine the observations for each dataset (Libraries and CAASPP) so that each one year has 58 observations for the 58 California counties. Then, we will combine the Library and CAASPP data into one dataset where each observation is one year in each county. Each observation would include the variables from both the library dataset and the CAASPP dataset.
#
# ### Dataset #3 (updated from Data Checkpoint)
# Dataset Name: California - County Population by Characteristics: 2010-2019 & 2020-2022
#
# Link to the dataset: [County Population by Characteristics: 2010-2019](https://www.census.gov/data/datasets/time-series/demo/popest/2010s-counties-detail.html) | [County Population by Characteristics: 2020-2022](https://www.census.gov/data/datasets/time-series/demo/popest/2020s-counties-detail.html)
#
# Number of observations: 58 counties
#
# Number of variables: Before wrangling, this dataset contains 95 variables. However, our variables of focus are ‘CTYNAME’, ‘YEAR’, and ‘AGE513_TOT’ since the ages of children borrowers in California are around 5 to 14.
#
# We will primarily use the total number of children aged 5-13 per county within this dataset and the 'Children Borrowers' and the 'Circulation of Childrens Materials' columns from Dataset #1 to calculate the proportion of borrowers and circulated materials per 1,000 children.
#
# A potential confounding variable we discovered is that not all children who go to the library take the CAASPP tests, such as if they are homeschooled.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### #1 California Public Libraries Statistics

# %%
# import working with data libraries
import pandas as pd
import numpy as np

# import seaborn
import seaborn as sns

# import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (17, 5)
plt.rcParams.update({'font.size': 16})

# %%
# read in csv 
library_17 = pd.read_csv('./data/All-DataFY16-17.csv',  encoding='latin-1')

# select only columns we are interested in 
lib_var = ['County', 'Population of The Legal Service Area', 
        'Registered Users as of June 30', 'Children Borrowers', 
        'Library Visits', 'Total Operating Income', 'Circulation of Childrens Materials',
        "# of Children's Programs", "Children's Program Attendance"]
library_17 = library_17[lib_var]

# convert quantitative variables to floats 
library_17[lib_var[1:]] = library_17[lib_var[1:]].apply(lambda x: x.str.replace('$','')).apply(lambda x: x.str.replace(',','')).astype(np.float64)
library_17['Year'] = 2017

# do the same with other years
library_18 = pd.read_csv('./data/All-DataFY17-18.csv',  encoding='latin-1')
library_18 = library_18[lib_var]
library_18[lib_var[1:]] = library_18[lib_var[1:]].apply(lambda x: x.str.replace('$','')).apply(lambda x: x.str.replace(',','')).astype(np.float64)
library_18['Year'] = 2018

library_19 = pd.read_csv('./data/All-DataFY18-19.csv',  encoding='latin-1')
library_19 = library_19[lib_var]
library_19[lib_var[1:]] = library_19[lib_var[1:]].apply(lambda x: x.str.replace('$','')).apply(lambda x: x.str.replace(',','')).astype(np.float64)
library_19['Year'] = 2019

# since CAASPP is missing 2020 data, we cannot compare it with 2020 library data

library_21 = pd.read_csv('./data/All-DataFY20-21.csv',  encoding='latin-1')
# column names differ slightly from previous years, manually adjusted
library_21 = library_21[['1.35 County', '2.1 Population of The Legal Service Area', 
        '2.2 Registered Users as of June 30', '2.3 Children Borrowers', '7.2 Library Visits', 
        '3.5 Total Operating Income', '7.12 Circulation of Childrens Materials', 
        "# of Children's Programs (calculated)", "Children's Program Attendance"]]
# rename columns 
library_21.columns = lib_var
library_21[lib_var[1:]] = library_21[lib_var[1:]].apply(lambda x: x.str.replace('$','')).apply(lambda x: x.str.replace(',','')).astype(np.float64)
library_21['Year'] = 2021

library_22 = pd.read_csv('./data/All-DataFY21-22.csv',  encoding='latin-1')
library_22 = library_22[['1.36 County', '2.1 Population of The Legal Service Area', 
        '2.2 Registered Users as of June 30', '2.3 Children Borrowers', '7.2 Library Visits', 
        '3.5 Total Operating Income', "7.11 Circulation of Children's Materials", 
        "# of Children's Programs (calculated)", "Children's Program Attendance"]]
library_22.columns = lib_var
library_22[lib_var[1:]] = library_22[lib_var[1:]].apply(lambda x: x.str.replace('$','')).apply(lambda x: x.str.replace(',','')).astype(np.float64)
library_22['Year'] = 2022


libraries = pd.concat([library_17, library_18, library_19, library_21, library_22])
# Out:
# C:\Users\ariat\AppData\Local\Temp\ipykernel_19508\3841989476.py:12: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   library_17[lib_var[1:]] = library_17[lib_var[1:]].apply(lambda x: x.str.replace('$','')).apply(lambda x: x.str.replace(',','')).astype(np.float64)
# C:\Users\ariat\AppData\Local\Temp\ipykernel_19508\3841989476.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   library_18[lib_var[1:]] = library_18[lib_var[1:]].apply(lambda x: x.str.replace('$','')).apply(lambda x: x.str.replace(',','')).astype(np.float64)
# ...

# %%
# combine all rows in the same county
new_libraries = libraries.groupby(['County','Year']).aggregate('sum').reset_index()

# see what aggregated library dataset looks like
new_libraries
# Out:
#       County  Year  Population of The Legal Service Area  \
# 0    Alameda  2017                             1645359.0
# 1    Alameda  2018                             1660202.0
# 2    Alameda  2019                             1669301.0
# 3    Alameda  2021                             1656591.0
# 4    Alameda  2022                             1651979.0
# ..       ...   ...                                   ...
# 280     Yuba  2017                               74577.0
# 281     Yuba  2018                               74727.0
# 282     Yuba  2019                               77916.0
# 283     Yuba  2021                               79407.0
# 284     Yuba  2022                               82275.0
#
#      Registered Users as of June 30  Children Borrowers  Library Visits  \
# 0                         1144802.0            211353.0       7943160.0
# 1                         1166499.0            212589.0       7701703.0
# ...

# %% [markdown]
# ### #2 California Assessment of Student Performance and Progress (CAASPP) Smarter Balance Assessments

# %%
# read in score csv
caaspp_17 = pd.read_csv('./data/sb_ca2017_1_csv_v2.csv')

# drop all rows with null values?
# exclude all observations of Grade 11 and Grade 13 (all grades totals) 
caaspp_17 = caaspp_17[caaspp_17['Grade'] < 11] 

# exclude all observations of County Code 0 (whole state total)
caaspp_17 = caaspp_17[caaspp_17['County Code'] != 0]
                      
# select only District Code = 0 (individual county totals)
caaspp_17 = caaspp_17[caaspp_17['District Code'] == 0]

# select variables we are interested in 
ca_var = ['County Code', 'Test Year', 'Grade', 'Test Id', 'Mean Scale Score', 
          'Percentage Standard Exceeded', 'Percentage Standard Met', 'Percentage Standard Nearly Met', 
          'Percentage Standard Not Met']
caaspp_17 = caaspp_17[ca_var]

caaspp_17_test1 = caaspp_17[caaspp_17['Test Id'] == 1]
caaspp_17_test2 = caaspp_17[caaspp_17['Test Id'] == 2]

merge_var = ['County Code', 'Test Year', 'Grade', 'Test Id 2', 'Mean Scale Score 2', 
          'Percentage Standard Exceeded 2', 'Percentage Standard Met 2', 'Percentage Standard Nearly Met 2', 
          'Percentage Standard Not Met 2']
caaspp_17_test2.columns = merge_var

# now each county has grades 3-8, two rows per grade for ELA and math
caaspp_17 = caaspp_17_test1.merge(caaspp_17_test2)

#allow python to reallocate the memory
del caaspp_17_test1
del caaspp_17_test2

caaspp_17

# make separate columns for ELA (Test Id = 1) and math (Test Id = 2) (for mean and percentage columns)
# convert quantitative variables to float
# aggregate all rows by county code
# Out:
#      County Code  Test Year  Grade  Test Id Mean Scale Score  \
# 0              1       2017      3        1           2426.9
# 1              1       2017      4        1           2469.9
# 2              1       2017      5        1           2506.1
# 3              1       2017      6        1           2534.9
# 4              1       2017      7        1           2561.2
# ..           ...        ...    ...      ...              ...
# 343           58       2017      4        1           2439.2
# 344           58       2017      5        1           2475.8
# 345           58       2017      6        1           2496.9
# 346           58       2017      7        1           2515.6
# 347           58       2017      8        1           2521.0
#
#     Percentage Standard Exceeded Percentage Standard Met  \
# 0                          28.95                   20.40
# 1                          29.72                   21.00
# 2                          27.50                   25.95
# ...

# %%
caaspp_18 = pd.read_csv('./data/sb_ca2018_1_csv_v3.csv')
caaspp_18 = caaspp_18[caaspp_18['Grade'] < 11]
caaspp_18 = caaspp_18[caaspp_18['County Code'] != 0]
caaspp_18 = caaspp_18[caaspp_18['District Code'] == 0]
caaspp_18 = caaspp_18[ca_var]
caaspp_18_test1 = caaspp_18[caaspp_18['Test Id'] == 1]
caaspp_18_test2 = caaspp_18[caaspp_18['Test Id'] == 2]
caaspp_18_test2.columns = merge_var
caaspp_18 = caaspp_18_test1.merge(caaspp_18_test2)
del caaspp_18_test1
del caaspp_18_test2

caaspp_19 = pd.read_csv('./data/sb_ca2019_1_csv_v4.csv')
caaspp_19 = caaspp_19[caaspp_19['Grade'] < 11]
caaspp_19 = caaspp_19[caaspp_19['County Code'] != 0]
caaspp_19 = caaspp_19[caaspp_19['District Code'] == 0]
caaspp_19 = caaspp_19[ca_var]
caaspp_19_test1 = caaspp_19[caaspp_19['Test Id'] == 1]
caaspp_19_test2 = caaspp_19[caaspp_19['Test Id'] == 2]
caaspp_19_test2.columns = merge_var
caaspp_19 = caaspp_19_test1.merge(caaspp_19_test2)
del caaspp_19_test1
del caaspp_19_test2

caaspp_21 = pd.read_csv('./data/sb_ca2021_1_csv_v2.csv', delimiter='^')
caaspp_21 = caaspp_21[caaspp_21['Grade'] < 11]
caaspp_21 = caaspp_21[caaspp_21['County Code'] != 0]
caaspp_21 = caaspp_21[caaspp_21['District Code'] == 0]
#They capitalized the 'D' in 'Test ID'
ca_var2 = ['County Code', 'Test Year', 'Grade', 'Test ID', 'Mean Scale Score', 
          'Percentage Standard Exceeded', 'Percentage Standard Met', 'Percentage Standard Nearly Met', 
          'Percentage Standard Not Met']
caaspp_21 = caaspp_21[ca_var2]
caaspp_21.columns = ca_var
caaspp_21_test1 = caaspp_21[caaspp_21['Test Id'] == 1]
caaspp_21_test2 = caaspp_21[caaspp_21['Test Id'] == 2]
caaspp_21_test2.columns = merge_var
caaspp_21 = caaspp_21_test1.merge(caaspp_21_test2)
del caaspp_21_test1
del caaspp_21_test2

caaspp_22 = pd.read_csv('./data/sb_ca2022_1_csv_v1.csv', delimiter='^')
caaspp_22 = caaspp_22[caaspp_22['Grade'] < 11]
caaspp_22 = caaspp_22[caaspp_22['County Code'] != 0]
caaspp_22 = caaspp_22[caaspp_22['District Code'] == 0]
caaspp_22 = caaspp_22[ca_var2]
caaspp_22.columns = ca_var
caaspp_22_test1 = caaspp_22[caaspp_22['Test Id'] == 1]
caaspp_22_test2 = caaspp_22[caaspp_22['Test Id'] == 2]
caaspp_22_test2.columns = merge_var
caaspp_22 = caaspp_22_test1.merge(caaspp_22_test2)
del caaspp_22_test1
del caaspp_22_test2

# %%
#2021 has null values, the others don't
caaspp_21[caaspp_21.isna().any(axis=1)]
# Out:
#      County Code  Test Year  Grade  Test Id Mean Scale Score  \
# 270           46       2021      3        1              NaN
# 271           46       2021      4        1              NaN
# 272           46       2021      5        1              NaN
# 273           46       2021      6        1              NaN
#
#     Percentage Standard Exceeded Percentage Standard Met  \
# 270                          NaN                     NaN
# 271                          NaN                     NaN
# 272                          NaN                     NaN
# 273                          NaN                     NaN
#
#     Percentage Standard Nearly Met Percentage Standard Not Met  Test Id 2  \
# 270                            NaN                         NaN          2
# 271                            NaN                         NaN          2
# 272                            NaN                         NaN          2
# ...

# %%
#The county with the nulls is Sierra. A news search shows that in 2021, the CAASPP was optional in Sierra County
caaspp_21 = caaspp_21.dropna()
caaspp_21.shape
# Out:
# (344, 15)

# %%
#Append all years together
caaspp = pd.concat([caaspp_17, caaspp_18, caaspp_19, caaspp_21, caaspp_22], ignore_index=True)
del caaspp_17
del caaspp_18
del caaspp_19
del caaspp_21
del caaspp_22
caaspp.tail()
# Out:
#       County Code  Test Year  Grade  Test Id Mean Scale Score  \
# 1731           58       2022      4        1           2436.2
# 1732           58       2022      5        1           2474.9
# 1733           58       2022      6        1           2490.9
# 1734           58       2022      7        1           2511.4
# 1735           58       2022      8        1           2537.5
#
#      Percentage Standard Exceeded Percentage Standard Met  \
# 1731                        17.20                   19.35
# 1732                        14.66                   26.27
# 1733                         9.04                   24.89
# 1734                         8.24                   27.55
# 1735                         8.27                   31.30
#
#      Percentage Standard Nearly Met Percentage Standard Not Met  Test Id 2  \
# 1731                          22.61                       40.84          2
# 1732                          21.99                       37.09          2
# ...

# %%
#determine which rows aren't numerical...we see that some have asterisks
unique_values = caaspp['Mean Scale Score'].unique()
unique_values.sort()
unique_values
# Out:
# array(['*', '2353.5', '2358.4', ..., '2605.9', '2614.2', '2616.5'],
#       dtype=object)

# %%
#drop rows that have asterisks
asterisk_rows = caaspp[caaspp['Mean Scale Score'] == '*'].index.values
caaspp = caaspp.drop(labels=asterisk_rows)

#Same for mean scale score 2
asterisk_rows = caaspp[caaspp['Mean Scale Score 2'] == '*'].index.values
caaspp = caaspp.drop(labels=asterisk_rows)

# %%
# read in school code csv, which matches county codes to county name
county_names = pd.read_csv('./data/sb_ca2017entities_csv.csv')

# drop County Code = 0 (does not represent a county)
county_names = county_names[county_names['County Code'] != 0]

# we only need one row per county for its name
county_names = county_names[county_names['District Code'] == 0]

# select column with county names
county_names = county_names['County Name'].reset_index(drop=True)

# replace the school code column in caaspp with county_names
county_names = county_names.reset_index()
county_names['index'] += 1

mapping = dict(county_names[['index', 'County Name']].values)
caaspp['County Code'] = caaspp['County Code'].map(mapping)
caaspp = caaspp.rename(columns={'County Code': 'County Name'})

#drop sierra bc that county is not included in the library dataset
caaspp = caaspp.drop(caaspp[caaspp['County Name'] == 'Sierra'].index)

caaspp = caaspp.drop('Test Id', axis=1)
caaspp = caaspp.drop('Test Id 2', axis=1)

caaspp.columns = ['County Name', 'Test Year', 'Grade', 'Mean Scale Score ELA', 'Percent Exceeded ELA', 'Percent Met ELA', 
                'Percent Nearly Met ELA', 'Percent Not Met ELA', 'Mean Scale Score Math', 'Percent Exceeded Math', 'Percent Met Math', 
                'Percent Nearly Met Math', 'Percent Not Met Math']

caaspp.head()
# Out:
#   County Name  Test Year  Grade Mean Scale Score ELA Percent Exceeded ELA  \
# 0     Alameda       2017      3               2426.9                28.95
# 1     Alameda       2017      4               2469.9                29.72
# 2     Alameda       2017      5               2506.1                27.50
# 3     Alameda       2017      6               2534.9                23.51
# 4     Alameda       2017      7               2561.2                24.26
#
#   Percent Met ELA Percent Nearly Met ELA Percent Not Met ELA  \
# 0           20.40                  21.25               29.39
# 1           21.00                  17.59               31.69
# 2           25.95                  17.28               29.28
# 3           30.07                  22.62               23.80
# 4           32.75                  19.36               23.63
#
#   Mean Scale Score Math Percent Exceeded Math Percent Met Math  \
# 0                2443.8                 27.97            25.67
# ...

# %%
caaspp_numeric_vars = ['Mean Scale Score ELA', 'Percent Exceeded ELA', 'Percent Met ELA', 
                       'Percent Nearly Met ELA', 'Percent Not Met ELA', 'Mean Scale Score Math', 
                       'Percent Exceeded Math', 'Percent Met Math', 
                       'Percent Nearly Met Math', 'Percent Not Met Math']

caaspp[caaspp_numeric_vars] = caaspp[caaspp_numeric_vars].astype(np.float64)

caaspp.describe()
# Out:
#          Test Year        Grade  Mean Scale Score ELA  Percent Exceeded ELA  \
# count  1680.000000  1680.000000           1680.000000           1680.000000
# mean   2019.390476     5.498214           2490.457738             16.747494
# std       1.855701     1.708333             54.142953              7.476501
# min    2017.000000     3.000000           2353.500000              0.000000
# 25%    2018.000000     4.000000           2448.275000             11.077500
# 50%    2019.000000     5.000000           2497.100000             15.280000
# 75%    2021.000000     7.000000           2533.775000             21.192500
# max    2022.000000     8.000000           2616.500000             43.660000
#
#        Percent Met ELA  Percent Nearly Met ELA  Percent Not Met ELA  \
# count      1680.000000             1680.000000          1680.000000
# mean         27.281506               24.511613            31.459220
# std           6.133823                4.143882             8.241774
# ...

# %% [markdown]
# ### #3 California County Population by Characteristics: 2010-2019 & 2020-2022

# %%
# read in csv for population estimates 2010-2019
pop_17_19 = pd.read_csv('./data/cc-est2019-agesex-06.csv')

# select years 2017, 2018, 2019
pop_17_19 = pop_17_19[pop_17_19['YEAR'] > 9]

# select columns county name, year, and population ages 5-13
pop_17_19 = pop_17_19[['CTYNAME', 'YEAR', 'POPESTIMATE', 'AGE513_TOT']]
pop_17_19['YEAR'] = pop_17_19['YEAR'].replace({10: 2017, 11: 2018, 12: 2019})

# read in csv for population estimates 2020-2022
pop_21_22 = pd.read_csv('./data/cc-est2022-agesex-06.csv')

# select years 2021 and 2022
pop_21_22 = pop_21_22[pop_21_22['YEAR'] > 2]
pop_21_22 = pop_21_22[['CTYNAME', 'YEAR', 'POPESTIMATE', 'AGE513_TOT']]
pop_21_22['YEAR'] = pop_21_22['YEAR'].replace({3: 2021, 4: 2022})

population = pd.concat([pop_17_19, pop_21_22])
population = population.sort_values(by=['CTYNAME', 'YEAR'])

# %%
# add population of sierra county to plumas county
for p, s in zip(population[population['CTYNAME'] == 'Plumas County'].index, population[population['CTYNAME'] == 'Sierra County'].index):
    population.loc[p, 'AGE513_TOT'] += population.loc[s, 'AGE513_TOT']
    population.loc[p, 'POPESTIMATE'] += population.loc[s, 'POPESTIMATE']

# %%
population = population.drop(population[population['CTYNAME'] == 'Sierra County'].index)

# %%
pop_prop = population.copy()
pop_prop['Child_Prop'] = pop_prop['AGE513_TOT'] / pop_prop['POPESTIMATE']
pop_prop.reset_index()
# Out:
#      index         CTYNAME  YEAR  POPESTIMATE  AGE513_TOT  Child_Prop
# 0        9  Alameda County  2017      1660196      173676    0.104612
# 1       10  Alameda County  2018      1666756      172464    0.103473
# 2       11  Alameda County  2019      1671329      171352    0.102524
# 3        2  Alameda County  2021      1643837      164923    0.100328
# 4        3  Alameda County  2022      1628997      159453    0.097884
# ..     ...             ...   ...          ...         ...         ...
# 280    693     Yuba County  2017        76578       10747    0.140341
# 281    694     Yuba County  2018        77557       11001    0.141844
# 282    695     Yuba County  2019        78668       11055    0.140527
# 283    230     Yuba County  2021        83216       11620    0.139637
# 284    231     Yuba County  2022        84310       11674    0.138465
#
# [285 rows x 6 columns]

# %%
population = population['AGE513_TOT'].tolist()
new_libraries['Child Population'] = population

# %%
# Create a new DataFrame for values per 1,000 people or per 1,000 children
libraries_per = new_libraries.copy()
libraries_per['Registered Users as of June 30'] = libraries_per['Registered Users as of June 30'] / libraries_per['Population of The Legal Service Area'] *1000
libraries_per['Library Visits'] = libraries_per['Library Visits'] / libraries_per['Population of The Legal Service Area'] *1000

# get values per 1,000 people/children
libraries_per['Children Borrowers'] = libraries_per['Children Borrowers'] / libraries_per['Child Population'] *1000
libraries_per['Circulation of Childrens Materials'] = libraries_per['Circulation of Childrens Materials'] / libraries_per['Child Population'] *1000
libraries_per["# of Children's Programs"] = libraries_per["# of Children's Programs"] / libraries_per['Child Population'] *1000
libraries_per["Children's Program Attendance"] = libraries_per["Children's Program Attendance"] / libraries_per['Child Population'] *1000
libraries_per.columns = ['County', 'Year', 'Population of The Legal Service Area', 'Registered Users Per 1k People', 'Children Borrowers Per 1k Children', 
                         'Library Visits Per 1k People', 'Total Operating Income', 'Circ. Childrens Materials Per 1k Children', "Children's Programs per 1k Children",
                       "Children's Program Attendance Per 1k Children", 'Child Population']
libraries_per
# Out:
#       County  Year  Population of The Legal Service Area  \
# 0    Alameda  2017                             1645359.0
# 1    Alameda  2018                             1660202.0
# 2    Alameda  2019                             1669301.0
# 3    Alameda  2021                             1656591.0
# 4    Alameda  2022                             1651979.0
# ..       ...   ...                                   ...
# 280     Yuba  2017                               74577.0
# 281     Yuba  2018                               74727.0
# 282     Yuba  2019                               77916.0
# 283     Yuba  2021                               79407.0
# 284     Yuba  2022                               82275.0
#
#      Registered Users Per 1k People  Children Borrowers Per 1k Children  \
# 0                        695.776423                         1216.938437
# 1                        702.624741                         1232.657250
# ...

# %%
libraries_per.describe()
# Out:
#               Year  Population of The Legal Service Area  \
# count   285.000000                          2.850000e+02
# mean   2019.400000                          6.940332e+05
# std       1.857986                          1.477609e+06
# min    2017.000000                          1.135000e+03
# 25%    2018.000000                          5.459000e+04
# 50%    2019.000000                          1.906240e+05
# 75%    2021.000000                          7.652450e+05
# max    2022.000000                          1.028329e+07
#
#        Registered Users Per 1k People  Children Borrowers Per 1k Children  \
# count                      285.000000                          285.000000
# mean                       531.989585                          926.679068
# std                        365.745346                          847.309042
# min                         80.771543                           -0.540249
# 25%                        325.027256                          428.663177
# ...

# %% [markdown]
# We see that some of the descriptive values indicate that there may be some negative numbers in the data. The library element definitions document explains that a negative one (-1) is used as a placeholder when a statistic was unavailable. They do not mean zero. For the remainder of our analysis, we will exclude values that are negative when looking at each column of interset. This does **not** mean we are dropping rows that have a negative value.

# %% [markdown]
# # Results
#
# ## Exploratory Data Analysis
#
# Carry out whatever EDA you need to for your project.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.

# %% [markdown]
# ### Exploration of Library and Population Data

# %%
# Distribution of library visits (per 1000 people in serviced area) across counties
ax = sns.histplot(data=libraries_per[libraries_per['Library Visits Per 1k People'] >= 0].groupby('County').agg('mean'), x='Library Visits Per 1k People')
ax.set_title('Distribution of library visits (per 1000 people in serviced area) across counties')
ax.axvline(libraries_per[libraries_per['Library Visits Per 1k People'] >= 0].groupby('County').agg('mean')['Library Visits Per 1k People'].mean(), color='darkred', label='mean')
ax.legend()
plt.show()

# %% [markdown]
# After looking at the distribution of library visits per 1000 people in serviced areas across California counties, there appears to be a right-skewed distribution with a mean of 2459 library visits per 1000 person. There is an outlier among this histogram, suggesting that a particular county may yield a much higher library visit count per 1000 people relative to the other counties.
#
# Although library visits are a good indicator of how regularly people participate and attend their local libraries, the variable does not provide as much insight into how old or how active these visitors are at the county libraries. In order to get a more specific gauge of the age distribution and activity level of the library visitors, we looked further into the distribution of children borrowers per 1000 children in California counties below.

# %%
# Distribution of children borrowers (per 1000 children in county population) across counties
ax = sns.histplot(data=libraries_per[libraries_per['Children Borrowers Per 1k Children'] >= 0].groupby('County').agg('mean'), x='Children Borrowers Per 1k Children', color='#d5a42b')
ax.set_title('Distribution of children borrowers (per 1000 children in county population) across counties')
ax.axvline(libraries_per[libraries_per['Children Borrowers Per 1k Children'] >= 0].groupby('County').agg('mean')['Children Borrowers Per 1k Children'].mean(), color='darkred', label='mean')
ax.legend()
plt.show()

# %% [markdown]
# Taking a look at this histogram, it seems that there is a right-skewed distribution of children borrowers per 1000 children in county population across California counties. The mean, as indicated by the red line, is 927, which suggests that there are 927 children borrowers per 1000 children in California counties on average. There is an outlier in the distribution, suggesting that there may be a county with a much higher rate of children borrowers per 1000 children than other counties in California.
#
# The distribution of children borrowers per 1000 children in California counties may be a stronger predictor of library activity than the number of library visits. A child borrower requires registration of the individual to be able to borrow books at the library. That level of commitment and activity at the library is ultimately what we are looking to compare with the CAASPP scores in ELA and mathematics per California county.

# %% [markdown]
# ### Exploration of CAASPP Reading Score Data
#
# In this section we are using scatterplots to see if there is a correlation between the amount of activity at libraries in a county and the CAASPP test performance of students grades 3-8 in that county. For now we are using "Percentage Standard Exceeded" as the metric for high performance on the CAASPP tests. A high percentage of students scoring in the "Percentage Standard Exceeded" range indicates that that county had many high-scoring students in that year. We plan to also plot Percentage Standard Met, Nearly Met, and Not Met to see if there are similar patterns.

# %%
# Compare circulation of children's materials with Percentage exceeded standard in ELA (2017)
fig, axs = plt.subplots(2, 3, figsize=(10, 5))
df_2017 = pd.DataFrame({'Circ. Childrens Materials Per 1k Children': libraries_per[libraries_per['Year']==2017]['Circ. Childrens Materials Per 1k Children'].reset_index(drop=True),
                       'Percent Exceeded ELA, Grade 3': caaspp[(caaspp['Test Year']==2017) & (caaspp['Grade']==3)]['Percent Exceeded ELA'].reset_index(drop=True),
                       'Percent Exceeded ELA, Grade 4': caaspp[(caaspp['Test Year']==2017) & (caaspp['Grade']==4)]['Percent Exceeded ELA'].reset_index(drop=True),
                       'Percent Exceeded ELA, Grade 5': caaspp[(caaspp['Test Year']==2017) & (caaspp['Grade']==5)]['Percent Exceeded ELA'].reset_index(drop=True),
                       'Percent Exceeded ELA, Grade 6': caaspp[(caaspp['Test Year']==2017) & (caaspp['Grade']==6)]['Percent Exceeded ELA'].reset_index(drop=True),
                       'Percent Exceeded ELA, Grade 7': caaspp[(caaspp['Test Year']==2017) & (caaspp['Grade']==7)]['Percent Exceeded ELA'].reset_index(drop=True),
                       'Percent Exceeded ELA, Grade 8': caaspp[(caaspp['Test Year']==2017) & (caaspp['Grade']==8)]['Percent Exceeded ELA'].reset_index(drop=True)})

sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded ELA, Grade 3', data=df_2017, ax=axs[0, 0]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded ELA, Grade 4', data=df_2017, ax=axs[0, 1]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded ELA, Grade 5', data=df_2017, ax=axs[0, 2]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded ELA, Grade 6', data=df_2017, ax=axs[1, 0]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded ELA, Grade 7', data=df_2017, ax=axs[1, 1]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded ELA, Grade 8', data=df_2017, ax=axs[1, 2]);

plt.tight_layout()

# %% [markdown]
# The graph above shows the relationship between Circulation of children's materials per 1,000 children and the percentage of test takers who exceeded the state standard in the English Language Arts test in 2017. Each graph represents a different grade. Grades 3 and 4 seem to show the strongest positive correlation between the circulation of children's materials in that county and the percentage of students who exceeded the standard.

# %%
# Compare circulation of children's materials with Percentage exceeded standard in Math (2017)
fig, axs = plt.subplots(2, 3, figsize=(10, 5))
df_2017 = pd.DataFrame({'Circ. Childrens Materials Per 1k Children': libraries_per[libraries_per['Year']==2017]['Circ. Childrens Materials Per 1k Children'].reset_index(drop=True),
                        'Percent Exceeded Math, Grade 3': caaspp[(caaspp['Test Year']==2017) & (caaspp['Grade']==3)]['Percent Exceeded Math'].reset_index(drop=True),
                        'Percent Exceeded Math, Grade 4': caaspp[(caaspp['Test Year']==2017) & (caaspp['Grade']==4)]['Percent Exceeded Math'].reset_index(drop=True),
                        'Percent Exceeded Math, Grade 5': caaspp[(caaspp['Test Year']==2017) & (caaspp['Grade']==5)]['Percent Exceeded Math'].reset_index(drop=True),
                        'Percent Exceeded Math, Grade 6': caaspp[(caaspp['Test Year']==2017) & (caaspp['Grade']==6)]['Percent Exceeded Math'].reset_index(drop=True),
                        'Percent Exceeded Math, Grade 7': caaspp[(caaspp['Test Year']==2017) & (caaspp['Grade']==7)]['Percent Exceeded Math'].reset_index(drop=True),
                        'Percent Exceeded Math, Grade 8': caaspp[(caaspp['Test Year']==2017) & (caaspp['Grade']==8)]['Percent Exceeded Math'].reset_index(drop=True)})

sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded Math, Grade 3', data=df_2017, ax=axs[0, 0]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded Math, Grade 4', data=df_2017, ax=axs[0, 1]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded Math, Grade 5', data=df_2017, ax=axs[0, 2]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded Math, Grade 6', data=df_2017, ax=axs[1, 0]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded Math, Grade 7', data=df_2017, ax=axs[1, 1]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded Math, Grade 8', data=df_2017, ax=axs[1, 2]);

plt.tight_layout()

# %% [markdown]
# The results for math look pretty similar to those of ELA. Grades 3 and 4 have evident positive correlations whereas the other grades are pretty scattered. We plan to do linear regression on the graphs with positive correlation.
#
# Let's take a look at some other years:

# %%
# Comparing Circulation of Children's Materials Per 1,000 Children with Percentage Standard Exceeded in ELA (2018)
fig, axs = plt.subplots(2, 3, figsize=(10, 5))
df_2018 = pd.DataFrame({'Circ. Childrens Materials Per 1k Children': libraries_per[libraries_per['Year']==2018]['Circ. Childrens Materials Per 1k Children'].reset_index(drop=True),
                       'Percent Exceeded ELA, Grade 3': caaspp[(caaspp['Test Year']==2018) & (caaspp['Grade']==3)]['Percent Exceeded ELA'].reset_index(drop=True),
                       'Percent Exceeded ELA, Grade 4': caaspp[(caaspp['Test Year']==2018) & (caaspp['Grade']==4)]['Percent Exceeded ELA'].reset_index(drop=True),
                       'Percent Exceeded ELA, Grade 5': caaspp[(caaspp['Test Year']==2018) & (caaspp['Grade']==5)]['Percent Exceeded ELA'].reset_index(drop=True),
                       'Percent Exceeded ELA, Grade 6': caaspp[(caaspp['Test Year']==2018) & (caaspp['Grade']==6)]['Percent Exceeded ELA'].reset_index(drop=True),
                       'Percent Exceeded ELA, Grade 7': caaspp[(caaspp['Test Year']==2018) & (caaspp['Grade']==7)]['Percent Exceeded ELA'].reset_index(drop=True),
                       'Percent Exceeded ELA, Grade 8': caaspp[(caaspp['Test Year']==2018) & (caaspp['Grade']==8)]['Percent Exceeded ELA'].reset_index(drop=True)})

sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded ELA, Grade 3', data=df_2018, ax=axs[0, 0]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded ELA, Grade 4', data=df_2018, ax=axs[0, 1]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded ELA, Grade 5', data=df_2018, ax=axs[0, 2]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded ELA, Grade 6', data=df_2018, ax=axs[1, 0]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded ELA, Grade 7', data=df_2018, ax=axs[1, 1]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded ELA, Grade 8', data=df_2018, ax=axs[1, 2]);

plt.tight_layout()

# %%
# Comparing Circulation of Children's Materials Per 1,000 Children with Percentage Standard Exceeded in Math (2018)
fig, axs = plt.subplots(2, 3, figsize=(10, 5))
df_2018 = pd.DataFrame({'Circ. Childrens Materials Per 1k Children': libraries_per[libraries_per['Year']==2018]['Circ. Childrens Materials Per 1k Children'].reset_index(drop=True),
                       'Percent Exceeded Math, Grade 3': caaspp[(caaspp['Test Year']==2018) & (caaspp['Grade']==3)]['Percent Exceeded Math'].reset_index(drop=True),
                       'Percent Exceeded Math, Grade 4': caaspp[(caaspp['Test Year']==2018) & (caaspp['Grade']==4)]['Percent Exceeded Math'].reset_index(drop=True),
                       'Percent Exceeded Math, Grade 5': caaspp[(caaspp['Test Year']==2018) & (caaspp['Grade']==5)]['Percent Exceeded Math'].reset_index(drop=True),
                       'Percent Exceeded Math, Grade 6': caaspp[(caaspp['Test Year']==2018) & (caaspp['Grade']==6)]['Percent Exceeded Math'].reset_index(drop=True),
                       'Percent Exceeded Math, Grade 7': caaspp[(caaspp['Test Year']==2018) & (caaspp['Grade']==7)]['Percent Exceeded Math'].reset_index(drop=True),
                       'Percent Exceeded Math, Grade 8': caaspp[(caaspp['Test Year']==2018) & (caaspp['Grade']==8)]['Percent Exceeded Math'].reset_index(drop=True)})

sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded Math, Grade 3', data=df_2018, ax=axs[0, 0]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded Math, Grade 4', data=df_2018, ax=axs[0, 1]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded Math, Grade 5', data=df_2018, ax=axs[0, 2]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded Math, Grade 6', data=df_2018, ax=axs[1, 0]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded Math, Grade 7', data=df_2018, ax=axs[1, 1]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded Math, Grade 8', data=df_2018, ax=axs[1, 2]);

plt.tight_layout()

# %% [markdown]
# In 2018, there is a clear positive correlation for grades 4 and 6 in both math and ELA, but not for the other grades. This is a change from the 2017 results, which showed positive correlations for grades 3 and 4.
#
# When the COVID-19 pandemic began, many libraries closed and schools went online. We hypothesize that this made a large difference in students' quality of education during 2020-2021 and in the next few cells we test to see if the positive correlations continue for post-lockdown years.

# %%
# Test for other years: post-COVID
# Compare circulation of children's materials with Percentage exceeded standard in Math (2021)
fig, axs = plt.subplots(2, 3, figsize=(10, 5))
df_2021 = pd.DataFrame({'Circ. Childrens Materials Per 1k Children': libraries_per[libraries_per['Year']==2021]['Circ. Childrens Materials Per 1k Children'].reset_index(drop=True),
                        'Percent Exceeded Math, Grade 3': caaspp[(caaspp['Test Year']==2021) & (caaspp['Grade']==3)]['Percent Exceeded Math'].reset_index(drop=True),
                        'Percent Exceeded Math, Grade 4': caaspp[(caaspp['Test Year']==2021) & (caaspp['Grade']==4)]['Percent Exceeded Math'].reset_index(drop=True),
                        'Percent Exceeded Math, Grade 5': caaspp[(caaspp['Test Year']==2021) & (caaspp['Grade']==5)]['Percent Exceeded Math'].reset_index(drop=True),
                        'Percent Exceeded Math, Grade 6': caaspp[(caaspp['Test Year']==2021) & (caaspp['Grade']==6)]['Percent Exceeded Math'].reset_index(drop=True),
                        'Percent Exceeded Math, Grade 7': caaspp[(caaspp['Test Year']==2021) & (caaspp['Grade']==7)]['Percent Exceeded Math'].reset_index(drop=True),
                        'Percent Exceeded Math, Grade 8': caaspp[(caaspp['Test Year']==2021) & (caaspp['Grade']==8)]['Percent Exceeded Math'].reset_index(drop=True)})

sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded Math, Grade 3', data=df_2021, ax=axs[0, 0]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded Math, Grade 4', data=df_2021, ax=axs[0, 1]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded Math, Grade 5', data=df_2021, ax=axs[0, 2]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded Math, Grade 6', data=df_2021, ax=axs[1, 0]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded Math, Grade 7', data=df_2021, ax=axs[1, 1]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded Math, Grade 8', data=df_2021, ax=axs[1, 2]);

plt.tight_layout()

# %%
# Compare circulation of children's materials with Percentage exceeded standard in ELA (2021)
fig, axs = plt.subplots(2, 3, figsize=(10, 5))
df_2021 = pd.DataFrame({'Circ. Childrens Materials Per 1k Children': libraries_per[libraries_per['Year']==2021]['Circ. Childrens Materials Per 1k Children'].reset_index(drop=True),
                        'Percent Exceeded ELA, Grade 3': caaspp[(caaspp['Test Year']==2021) & (caaspp['Grade']==3)]['Percent Exceeded ELA'].reset_index(drop=True),
                        'Percent Exceeded ELA, Grade 4': caaspp[(caaspp['Test Year']==2021) & (caaspp['Grade']==4)]['Percent Exceeded ELA'].reset_index(drop=True),
                        'Percent Exceeded ELA, Grade 5': caaspp[(caaspp['Test Year']==2021) & (caaspp['Grade']==5)]['Percent Exceeded ELA'].reset_index(drop=True),
                        'Percent Exceeded ELA, Grade 6': caaspp[(caaspp['Test Year']==2021) & (caaspp['Grade']==6)]['Percent Exceeded ELA'].reset_index(drop=True),
                        'Percent Exceeded ELA, Grade 7': caaspp[(caaspp['Test Year']==2021) & (caaspp['Grade']==7)]['Percent Exceeded ELA'].reset_index(drop=True),
                        'Percent Exceeded ELA, Grade 8': caaspp[(caaspp['Test Year']==2021) & (caaspp['Grade']==8)]['Percent Exceeded ELA'].reset_index(drop=True)})

sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded ELA, Grade 3', data=df_2021, ax=axs[0, 0]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded ELA, Grade 4', data=df_2021, ax=axs[0, 1]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded ELA, Grade 5', data=df_2021, ax=axs[0, 2]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded ELA, Grade 6', data=df_2021, ax=axs[1, 0]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded ELA, Grade 7', data=df_2021, ax=axs[1, 1]);
sns.scatterplot(x='Circ. Childrens Materials Per 1k Children', y='Percent Exceeded ELA, Grade 8', data=df_2021, ax=axs[1, 2]);

plt.tight_layout()

# %% [markdown]
# In 2021 it can be seen that there is no longer a clear positive correlation in any grade between the circulation of children's materials and the percentage of students who exceeded the standard.

# %% [markdown]
# ### Choropleth map exploration

# %% [markdown]
# Let's begin to look into how the data is distributed spatially.

# %%
#import visualization tools
import geopandas as gpd
from mpl_toolkits.axes_grid1 import make_axes_locatable
#import statistical tools
from libpysal import weights
from scipy.stats import pearsonr
from esda.moran import Moran

#read in geoJSON file, remove unnecessary columns (not sure if we need OBJECTID or AdminRegion though)
ca_counties_FIPS = gpd.read_file('https://gis-calema.opendata.arcgis.com/datasets/59d92c1bf84a438d83f78465dce02c61_0.geojson?outSR=%7B%22latestWkid%22%3A3857%2C%22wkid%22%3A102100%7D')
ca_counties_FIPS = ca_counties_FIPS[['CountyName', 'County_FIPS_ID', 'geometry']]
ca_counties_FIPS = ca_counties_FIPS.drop( #removing Sierra County as data was merged with Plumas
    ca_counties_FIPS[ca_counties_FIPS['CountyName'] == 'Sierra'].index).reset_index(drop=True)
ca_counties_FIPS.head()
# Out:
#   CountyName County_FIPS_ID                                           geometry
# 0    Alameda            001  MULTIPOLYGON (((-122.26853 37.90446, -122.2682...
# 1     Alpine            003  POLYGON ((-119.93433 38.80882, -119.93426 38.8...
# 2     Amador            005  POLYGON ((-120.25766 38.58033, -120.25735 38.5...
# 3      Butte            007  POLYGON ((-121.63427 40.00127, -121.63428 40.0...
# 4  Calaveras            009  POLYGON ((-120.20981 38.50033, -120.20961 38.5...

# %%
#add the Registered Users and Children Borrowers data to plot to the geodataframe
FIPS_data = ca_counties_FIPS.copy()
FIPS_data.insert(2, 'Registered Users Per 1k People', libraries_per['Registered Users Per 1k People'])
FIPS_data.insert(2, 'Children Borrowers Per 1k Children', libraries_per['Children Borrowers Per 1k Children'])

#adding population proportion to FIPS dataframe
population_2017 = pop_prop[pop_prop['YEAR'] == 2017].reset_index(drop=True)
FIPS_data.insert(4, 'Child Proportion', population_2017['Child_Prop'])

#adding percent of grade 4 students who exceeded on ELA in 2017
caaspp_17Exceed = caaspp[(caaspp['Test Year']==2017) & (caaspp['Grade']==4)]['Percent Exceeded ELA'].reset_index(drop=True)
FIPS_data.insert(4, 'Exceeded, Grade 4, 2017', caaspp_17Exceed)

#adding lib childrens book circulation for 2017
libcirc_2017 = libraries_per[libraries_per['Year']==2017]['Circ. Childrens Materials Per 1k Children'].reset_index(drop=True)
FIPS_data.insert(4, 'Circ. Child Materials, 2017', libcirc_2017)

FIPS_data.head()
# Out:
#   CountyName County_FIPS_ID  Children Borrowers Per 1k Children  \
# 0    Alameda            001                         1216.938437
# 1     Alpine            003                         1232.657250
# 2     Amador            005                         1360.532705
# 3      Butte            007                         1175.136276
# 4  Calaveras            009                         1152.019717
#
#    Registered Users Per 1k People  Circ. Child Materials, 2017  \
# 0                      695.776423                 39203.246275
# 1                      702.624741                 21523.364486
# 2                      723.489652                  6490.284525
# 3                      769.452448                 12418.116194
# 4                      727.326437                 12102.503294
#
#    Exceeded, Grade 4, 2017  Child Proportion  \
# 0                    29.72          0.104612
# 1                    18.18          0.096310
# 2                    19.44          0.074801
# ...

# %%
#plotting child borrowers and all registered users
fig, axs = plt.subplots(1, 2, figsize=(15, 5))
for ax in axs:
    divider = make_axes_locatable(ax)

FIPS_data.plot(column='Registered Users Per 1k People', ax=axs[0], cmap='GnBu', legend=True,
               legend_kwds={"label": "Registered Users Per 1k People", "orientation": "vertical"});

FIPS_data.plot(column='Children Borrowers Per 1k Children', ax=axs[1], cmap='GnBu', legend=True,
               legend_kwds={"label": "Children Borrowers Per 1k Children", "orientation": "vertical"});

#seeing the distribution
fig, axs = plt.subplots(1, 2, figsize=(20, 5))

sns.distplot(FIPS_data['Registered Users Per 1k People'], ax=axs[0])
sns.distplot(FIPS_data['Children Borrowers Per 1k Children'], ax=axs[1])
#from this distplot it seems like most are concentrated between 125 and 1100 with a few around 2600 registered users/person
# Out:
# c:\Users\ariat\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\ariat\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Children Borrowers Per 1k Children', ylabel='Density'>

# %%
#checking distribution if we only look at the lower half of the Childrens Borrowers
FIPS_data_filtered = FIPS_data[FIPS_data['Children Borrowers Per 1k Children'] < 4000]


sns.distplot(FIPS_data_filtered['Children Borrowers Per 1k Children'])


fig, ax = plt.subplots(1, 1, figsize=(10, 7))
divider = make_axes_locatable(ax)
FIPS_data_filtered.plot(column='Children Borrowers Per 1k Children', ax=ax, cmap='GnBu', legend=True,
               legend_kwds={"label": "Children Borrowers Per 1k Children, filtered", "orientation": "vertical"});
# Out:
# c:\Users\ariat\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Let's see which counties have the higher section of registered users per 1K people versus Childrens Borrowers...
display(FIPS_data[FIPS_data['Children Borrowers Per 1k Children'] > 4000])
display(FIPS_data[FIPS_data['Registered Users Per 1k People'] > 2000])
#... and the rest of the library data for those counties to see if any other columns stands out
#libraries_per[libraries_per['County'].isin(['Colusa', 'Contra Costa', 'Del Norte', 'El Dorado', 'Fresno'])].head()
# Out:
#      CountyName County_FIPS_ID  Children Borrowers Per 1k Children  \
# 5        Colusa            011                         4990.654206
# 6  Contra Costa            013                         6418.604651
# 7     Del Norte            015                         5263.157895
# 8     El Dorado            017                         5728.260870
# 9        Fresno            019                         5945.054945
#
#    Registered Users Per 1k People  Circ. Child Materials, 2017  \
# 5                     2622.936577                  5663.934426
# 6                     2740.901213                 21434.951732
# 7                     2813.253012                  2581.639344
# 8                     2969.162996                 17913.219126
# 9                     2446.666667                  5510.068793
#
#    Exceeded, Grade 4, 2017  Child Proportion  \
# 5                    10.48          0.141341
# 6                    28.64          0.116923
# ...

# %% [markdown]
# We notice that the counties with the highest Children Borrowers per 1K children are the same as the counties with the most Registered Users per 1K people, which makes sense. However, in the distribution plots comparing both categories, we see that the skew is different on the left peak.
#
# To further analyze our data in regards to the choropleth maps, we will carry out spatial autocorrelation. This may reveal if there exists a statewide spatial autocorrelation that influences the performance of students in state exams and library attendance or circulation or if it is a random distribution. We begin with analyzing Children Borrowers per 1K children.

# %%
#SPATIAL AUTOCORRELATION (non-filtered)
y = FIPS_data['Children Borrowers Per 1k Children']
yb = y > y.median()
labels = ["0 Low", "1 High"]
yb = [labels[i] for i in 1*yb] 
FIPS_data['yb'] = yb

#SPATIAL AUTOCORRELATION GRAPH(non-filtered)
fig = plt.figure(figsize=(12,10))
ax = plt.gca()
FIPS_data.plot(column='yb', cmap='binary',
        edgecolor='grey', legend=True, ax=ax);

# Check for spatial autocorrelation using Moran's I
w_knn = weights.KNN.from_dataframe(FIPS_data, k=5)
moran = Moran(FIPS_data['Children Borrowers Per 1k Children'], w_knn)
print("Moran's I:", moran.I)
print("p-value:", moran.p_sim)
#weak negative correlation (disimilar values tend to be closer together) and it is not significant..
# Out:
# Moran's I: -0.09892173755998583
# p-value: 0.116

# %% [markdown]
# The Moran's I value indicates a tendency towards clustering with a positive number and a tendency towards dispersal with a negative number on a scale from 1 to -1. With a value of -0.09, there is a slight tendency towards negative spatial autocorrelation. The p-value of 0.143, if going by the standard 0.05, indicates the correlation is not statistically significant.

# %% [markdown]
# Next, we will map the CAASPP result data that we analyzed with the scatterplots in the Exploration of CAASPP Reading Score Data.

# %% [markdown]
# Next, we will look at the spatial autocorrelation of the proportion of children to the total county population.

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 7))
divider = make_axes_locatable(ax)
FIPS_data.plot(column='Child Proportion', ax=ax, cmap='GnBu', legend=True,
               legend_kwds={"label": "Proportion of Children to General Population", "orientation": "vertical"});

#dichotomize data and plot visualization
y = FIPS_data['Child Proportion']
yb = y > y.median()
labels = ["0 Low", "1 High"]
yb = [labels[i] for i in 1*yb] 
FIPS_data['yb'] = yb

fig = plt.figure(figsize=(12,10))
ax = plt.gca()
FIPS_data.plot(column='yb', cmap='binary',
        edgecolor='grey', legend=True, ax=ax);

#calculate correlation: even less significant and weak positive correlation (similar values tend to be closer)
w_knn = weights.KNN.from_dataframe(FIPS_data, k=5)
moran = Moran(FIPS_data['Child Proportion'], w_knn)
print("Moran's I:", moran.I)
print("p-value:", moran.p_sim)
# Out:
# Moran's I: 0.26182074733023497
# p-value: 0.002

# %%
sns.distplot(FIPS_data['Exceeded, Grade 4, 2017'])

fig, ax = plt.subplots(1, 1, figsize=(10, 7))
divider = make_axes_locatable(ax)
FIPS_data.plot(column='Exceeded, Grade 4, 2017', ax=ax, cmap='GnBu', legend=True,
               legend_kwds={"label": "Test scores", "orientation": "vertical"});
#dichotomize data and visualize
y = FIPS_data['Exceeded, Grade 4, 2017']
yb = y > y.median()
labels = ["0 Low", "1 High"]
yb = [labels[i] for i in 1*yb] 
FIPS_data['yb'] = yb

fig = plt.figure(figsize=(12,10))
ax = plt.gca()
FIPS_data.plot(column='yb', cmap='binary',
        edgecolor='grey', legend=True, ax=ax);

#calculate correlation 
w_knn = weights.KNN.from_dataframe(FIPS_data, k=5)
# Check for spatial autocorrelation using Moran's I
moran = Moran(FIPS_data['Exceeded, Grade 4, 2017'], w_knn)
print("Moran's I:", moran.I) #Unsure why the value is nan
print("p-value:", moran.p_sim)
# Out:
# c:\Users\ariat\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Moran's I: 0.34448666243702597
# p-value: 0.001

# %%
sns.distplot(FIPS_data['Circ. Child Materials, 2017'])

fig, ax = plt.subplots(1, 1, figsize=(10, 7))
divider = make_axes_locatable(ax)
FIPS_data.plot(column='Circ. Child Materials, 2017', ax=ax, cmap='GnBu', legend=True,
               legend_kwds={"label": "Lib data", "orientation": "vertical"});
#correlation graph
y = FIPS_data['Circ. Child Materials, 2017']
yb = y > y.median()
labels = ["0 Low", "1 High"]
yb = [labels[i] for i in 1*yb] 
FIPS_data['yb'] = yb

#dichotomize data and visualize
fig = plt.figure(figsize=(12,10))
ax = plt.gca()
FIPS_data.plot(column='yb', cmap='binary',
        edgecolor='grey', legend=True, ax=ax);

#correlation 
w_knn = weights.KNN.from_dataframe(FIPS_data, k=5)
# Check for spatial autocorrelation using Moran's I
moran = Moran(FIPS_data['Circ. Child Materials, 2017'], w_knn)
print("Moran's I:", moran.I)
print("p-value:", moran.p_sim)
# Out:
# c:\Users\ariat\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Moran's I: 0.4454652853614244
# p-value: 0.001

# %%
#seeing which county has libraries that are on the high end of circulation of childrens materials...
#...versus the distribution of percentage of students exceeded
filtered_data = FIPS_data[FIPS_data['yb'] == '1 High'].copy()
filtered_data['geometry'] = filtered_data['geometry'].centroid

base = FIPS_data.plot(column='Exceeded, Grade 4, 2017', cmap='GnBu', zorder = 1)
filtered_data.plot(ax=base, marker='o', markersize=5, color='black', zorder=2)

plt.show()
# Out:
# C:\Users\ariat\AppData\Local\Temp\ipykernel_19508\15420506.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   filtered_data['geometry'] = filtered_data['geometry'].centroid

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# Given our research question, one of the primary concerns we have regards the privacy of the children whose data we will be collecting. The data we wish to utilize will track participation at public libraries as well as student test scores. We understand that while parents or guardians may have consented to allow the collection of their children's data, it is unlikely that the children themselves can offer truly informed consent to have their data collected and used. For this reason, we propose to utilize only data that refrains from including all personal identifying information except for the age of children. Additionally, in our analysis, we aim to only use this data in aggregate — never singling out a single data point for commentary on that individual. Another privacy concern hinges on the fact that some of our data includes attendance rates for children's programs at public libraries. To protect the privacy and safety of the children who attend these programs, we will withhold information about the times and locations of the programs as well as consider only using the program data in aggregate by county. Lastly, considering that these libraries are public institutions, the data must be safeguarded through strong security measures to prevent hacking, data leaks, and other security breaches.
#
# The ethics concerns we have for our data, however, extend beyond just privacy. One issue that might arise from the data is the stigmatization of certain communities or school systems. Since we include performance data on standardized tests as well as library attendance habits, viewers may interpret these as metrics to profile certain groups or communities. In addition, inherent biases can impact the validity and fairness of research findings, which may result in overrepresentation or underrepresentation of particular demographics and socioeconomic groups. Lastly, when collecting data within communities, it is imperative to implement responsible measures and practices that leave the community feeling safe and at ease. It is important in our analysis to remind readers that standardized test scores are not a holistic measure of an individual's capabilities nor is library attendance an accurate means to assess a community's habits.

# %% [markdown]
# # Team Expectations

# %% [markdown]
# * Each team member will attend our weekly group meetings unless they indicate they cannot attend beforehand.
# * Each team member will communicate any concerns, questions, or ideas with the other team members through our designated group chat or during our group meetings.
# * Each team member will complete their designated tasks by the deadlines determined by the team unless they communicate that they need more time to complete them.
# * Each team member will contribute equally across the entire project submission.
# * Each team member will regularly check in with each other to ensure good progress is being made toward the final project.

# %% [markdown]
# # Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 2/08  |  7:00 PM | Read through COGS 108 Team Policies; look for data sets about school rankings, student academic performance  | Discuss **Project Proposal**. Complete Team Expectations and Project Timeline Proposal. Assign the rest of the sections of the Project Proposal to the team members. |
# | 2/11  |  **By 10:00 PM** |  **Project Proposal Submission** |  |
# | 2/13  | 6:00 PM  | Complete assigned Project Proposal section and review group work for submission. | Discuss **Data** and Project Proposal feedback.   |
# | 2/20  | 6:00 PM  | Import and wrangle data. | Discuss Project Proposal feedback and finalize **Data**. Discuss **EDA** and project tasks.   |
# | 2/25 | 3:00 PM | Research additional datasets. | Finalize Data. Apply feedback from the Project Proposal. Introduce EDA. |
# | **2/25 DEADLINE**  | **Before 11:59 PM**  | **Checkpoint #1: DATA** |  |
# | 2/29  | 6:00 PM  | Submit Data and brainstorm **EDA** approach.  | Finalize **EDA** plan and assign project **tasks**. |
# | 3/3 | 3:00 PM | Work on assigned project tasks. | Discuss Data feedback. Finalize EDA plan and discuss progress on project tasks. |
# | 3/7  | 6:00 PM  | Complete **EDA**, plan assigned tasks, outline of Analysis.  | Review **EDA**, discuss **analysis**, and finalize task plans. |
# | **3/10 DEADLINE**  | **Before 11:59 PM**  | **Checkpoint #2: EDA** |  |
# | 3/12  | 6:00 PM  | Complete Analysis and draft of results, discussion, and conclusion. | Review drafts and edit the full project draft. Plan the **video**. |
# | 3/19  | 6:00 PM  | Prepare the video script and presentation.| Review presentation and film **final video**. Submit **Final Report**. |
# | **3/20 DEADLINE**  | **Before 11:59 PM**  | **DUE Final Report, Final Video, Team Evaluation, & Post Course Survey (EC)** |  |
